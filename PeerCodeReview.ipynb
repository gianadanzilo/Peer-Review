# %% [markdown]
# # Peer Code Review

# %% [markdown]
# ## Question 1

# %% [markdown]
# The code is well structured and readable, with clear headers and flow across the three notebooks. However, the working directory is hardcoded using setwd() in multiple separate code chunks, instead of one set code at the top. This is redundant and makes replication harder. The data loading notebooks (hcris_data.ipynb and hcris-combine.ipynb) could also be consolidated into a single script to reduce the number of files the reviewer needs to run. Additionally, the use of p_load with a large list of packages at the top is convenient but loads a lot of libraries that may not all be necessary for every analysis, which is inefficient and can slow down rendering.

# %% [markdown]
# ## Question 2

# %% [markdown]
# The results were consistent across both analyses. For question 1, both submissions showed a similar trend in hospitals filing duplicate reports, with counts that range from 70 to 115 hospitals per year from 2009-2019, peaking around 2018. For question 2, my analysis found 6,793 unique hospital IDs while Tammy found 6,897, which is a difference of about 104 hospitals, probably due to differences in how duplicate reports were handled. The violin plots for Questions 3 and 4 showed the same overall shape and scale on a log axis, suggesting consistent charge and price distributions. For Question 5, both analyses showed the penalized share rising sharply from 2012 to 2013-2014 and stabilizing around 35-40%, through my estimates were slightly lower overall. For questions 6-9, the OLS and IV regression results showed the same directional findings. Across most specifications, net penalty coefficients were small and statistically insignificant, although the exact point estimates differed somewhat, likely due to minor differences in sample construction.

# %% [markdown]
# ## Question 3

# %% [markdown]
# I was able to clone the repository successfully using git clone. However, full replication was not possible without manual path changes. The working directory is hardcoded to Tammy's local machine (/Users/tammydang/Downloads/EMORY/ECON-470/) in multiple places throughout the code. The data files referenced in the notebooks (hcris_data_2009-2019.csv, HCRIS_Data_v1996_2010.csv) are not included in the repo and must be sourced separately. The README file in the repo was empty, providing no setup instructions. I was able to review the analysis by comparing the pre-rendered analysis3.pdf output directly.

# %% [markdown]
# ## Question 4

# %% [markdown]
# The biggest obstacle to replication was the use of user specific file paths throughout the code (meaning, files that only exist in her computer). A simple fix would be to use relative paths or to define the base path to a single variable at the top of the file so that reviewers only need to change it once. Also, the raw data files should either be included in the repo in a data folder or linked to a public download source in the README. Adding a short README with setup instructions (like required packages, folder structure, or file run order) would significantly improve replicability for any reviewer.

# %% [markdown]
# ## Question 5

# %% [markdown]
# Reviewing this code reinforced for me the importance of using relative file paths and writing a clear README, two things I could improve in my own submissions. Tammy's Q6 write-up interpreting the OLS results was also more thorough than mine, so I will model future write-ups more closely to her style of describing the coefficient-level findings rather than just presenting the table.
